# %% [markdown]
# # Şekil indir

# %%
link = 'https://upload.wikimedia.org/wikipedia/commons/d/d8/Black_body_realization.svg'
filename = link.split('/')[-1]
filenameNOext = filename.split('.')[0]
ext = filename.split('.')[-1]
print filename
print ext
# Out:
# Black_body_realization.svg
# svg

# %%
#wget -e robots=off --wait 1
# !wget $link
# Out:
# --2018-09-23 22:22:55--  https://upload.wikimedia.org/wikipedia/commons/d/d8/Black_body_realization.svg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 103.102.166.240, 2001:df2:e500:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|103.102.166.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2254 (2,2K) [image/svg+xml]
# Saving to: ‘Black_body_realization.svg’
#
# 100%[======================================>] 2.254       --.-K/s   in 0s
#
# 2018-09-23 22:22:57 (27,9 MB/s) - ‘Black_body_realization.svg’ saved [2254/2254]

# %%
# !tree -L 1
# Out:
# .
# ├── Black_body_realization.svg
# ├── Leptonic_event_in_Gargamelle_bubble_chamber.jpg
# ├── Mplwp_blackbody_lambda_planck-wien-rj_5800K.png
# ├── Mplwp_blackbody_nu_planck-wien-rj_5800K.png
# └── sekil_indir.ipynb
#
# 0 directories, 5 files

# %% [markdown]
# ## svg --> png

# %%
# !inkscape -D -z --file="$filenameNOext".svg --export-pdf="$filenameNOext".pdf --export-latex

# %% [markdown]
# ## dosya ismi değiştir

# %%
# !mv $filename damped_oscillations.$ext

# %%
# !tree -L 1
# Out:
# .
# ├── Black_body_realization.pdf
# ├── Black_body_realization.pdf_tex
# ├── Black_body_realization.svg
# ├── Leptonic_event_in_Gargamelle_bubble_chamber.jpg
# ├── Mplwp_blackbody_lambda_planck-wien-rj_5800K.png
# ├── Mplwp_blackbody_nu_planck-wien-rj_5800K.png
# └── sekil_indir.ipynb
#
# 0 directories, 7 files

# %% [markdown]
# # Şekil düzenleme

# %%
# http://matthiaseisen.com/pp/patterns/p0201/
import matplotlib.pyplot as plt
import PIL as pil
img001 = pil.Image.open('Polar_coordinates_with_unit_vectors.png')
img001 = img001.rotate(-90, expand=True)
img001.save("Polar_coordinates_with_unit_vectors_90.png")
# !ls
# Out:
# 2010_mavericks_competition.jpg	neutron_star_vibrations.png
# basit_harmonik_hareket.png	Oscillating_pendulum.gif
# butterfly_pupa.jpg		PenduloTmg.gif
# earth_vibration_mods.gif	Polar_coordinates_with_unit_vectors_90.png
# fetus_heartbeat.gif		Polar_coordinates_with_unit_vectors.png
# funGifs				sekil_indir.ipynb
# Harmonic_oscillator.png		SimplePendulum_gen_coords.png
# Harmonic_oscillator.svg		uniform_circular_motion.gif
# LC_circuit.gif

# %%
pil.Image.open('Polar_coordinates_with_unit_vectors_90.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=807x1280 at 0x7FD57AAE36D0>

# %% [markdown]
# # HTML Tablo Örnekleri
#
# http://daydreamsgirl.com/articles/how-to-make-and-insert-a-simple-html-table-with-images-for-blogs/

# %% [markdown]
# <table border="1" cellpadding="5" width="500">
# <tbody>
# <tr>
# <td align="center" valign="center"><a href="http://istockphoto.com/file_closeup?id=9685054-romantic-couple.php&amp;refnum=daydreamsgirl" target="_blank"><img src="http://daydreamsgirl.com/articles/images/sk-78.jpg" title="Click to license this image at iStockphoto" alt="silhouette couple"></a><p></p>
# <p>Caption text centered under the image.</p></td>
# <td align="center" valign="center"><a href="http://istockphoto.com/file_closeup?id=9429507-holding-hands.php&amp;refnum=daydreamsgirl" target="_blank"><img src="http://daydreamsgirl.com/articles/images/sk-80.jpg" title="Click to license this image at iStockphoto" alt="holding hands silhouette"></a><p></p>
# <p>Caption text centered under the image.</p></td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# <div>
# <table border="1" cellpadding="5" width="500">
# <tbody>
# <tr>
# <td align="center" valign="center"><a href="http://istockphoto.com/file_closeup?id=9429507-holding-hands.php&amp;refnum=daydreamsgirl" target="_blank"><img src="http://daydreamsgirl.com/articles/images/sk-80.jpg" title="Click to license this image at iStockphoto" alt="Silhouette of couple holding hands"></a></td>
# <td align="center" valign="center">This text is in the table data cell on the right.</td>
# </tr>
# </tbody>
# </table>
# </div>

# %% [markdown]
# ## SVG-Edit

# %%
# %%html
# <iframe width=1200 height= 800 src="https://svg-edit.github.io/svgedit/releases/svg-edit-2.8.1/svg-editor.html"></iframe>
# Out:
# <iframe width=1200 height= 800 src="https://svg-edit.github.io/svgedit/releases/svg-edit-2.8.1/svg-editor.html"></iframe>

# %%
# %%html
# <iframe width=1200 height= 800 src="http://194.27.186.147:8889/view/Downloads/svgedit/editor/svg-editor.html"></iframe>
# Out:
# <iframe width=1200 height= 800 src="http://194.27.186.147:8889/view/Downloads/svgedit/editor/svg-editor.html"></iframe>
